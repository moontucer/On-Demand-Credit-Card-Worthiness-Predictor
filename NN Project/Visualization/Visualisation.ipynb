# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/mountasser/Downloads/clean_data.csv")

# %%
data.shape
# Out:
# (9709, 20)

# %%
data.columns.tolist()
# Out:
# ['ID',
#  'Gender',
#  'Own_car',
#  'Own_property',
#  'Work_phone',
#  'Phone',
#  'Email',
#  'Unemployed',
#  'Num_children',
#  'Num_family',
#  'Account_length',
#  'Total_income',
#  'Age',
#  'Years_employed',
#  'Income_type',
#  'Education_type',
#  'Family_status',
#  'Housing_type',
#  'Occupation_type',
#  'Target']

# %%
percent_accepted = data.Target[data.Target==1].sum() * 100 / len(data)

# %%
percent_accepted
# Out:
# 13.214543207333403

# %%
data['Target'].value_counts()
# Out:
# 0    8426
# 1    1283
# Name: Target, dtype: int64

# %%
data.Num_children.unique().tolist()
# Out:
# [0, 1, 3, 2, 4, 5, 14, 19, 7]

# %%
data.describe()
# Out:
#                  ID       Gender      Own_car  Own_property   Work_phone  \
# count  9.709000e+03  9709.000000  9709.000000   9709.000000  9709.000000
# mean   5.076105e+06     0.348749     0.367700      0.671542     0.217427
# std    4.080270e+04     0.476599     0.482204      0.469677     0.412517
# min    5.008804e+06     0.000000     0.000000      0.000000     0.000000
# 25%    5.036955e+06     0.000000     0.000000      0.000000     0.000000
# 50%    5.069449e+06     0.000000     0.000000      1.000000     0.000000
# 75%    5.112986e+06     1.000000     1.000000      1.000000     0.000000
# max    5.150479e+06     1.000000     1.000000      1.000000     1.000000
#
#              Phone        Email   Unemployed  Num_children   Num_family  \
# count  9709.000000  9709.000000  9709.000000   9709.000000  9709.000000
# mean      0.287671     0.087548     0.174683      0.422804     2.182614
# std       0.452700     0.282650     0.379716      0.767019     0.932918
# ...

# %%
quantile1, quantile2 = np.percentile(data.Num_children, [25,75])

# %%
data.dtypes
# Out:
# ID                   int64
# Gender               int64
# Own_car              int64
# Own_property         int64
# Work_phone           int64
# Phone                int64
# Email                int64
# Unemployed           int64
# Num_children         int64
# Num_family           int64
# Account_length       int64
# Total_income       float64
# Age                float64
# Years_employed     float64
# Income_type         object
# Education_type      object
# Family_status       object
# Housing_type        object
# Occupation_type     object
# Target               int64
# dtype: object

# %%
data.head()
# Out:
#         ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0  5008804       1        1             1           1      0      0
# 1  5008806       1        1             1           0      0      0
# 2  5008808       0        0             1           0      1      1
# 3  5008812       0        0             1           0      0      0
# 4  5008815       1        1             1           1      1      1
#
#    Unemployed  Num_children  Num_family  Account_length  Total_income  \
# 0           0             0           2              15      427500.0
# 1           0             0           2              29      112500.0
# 2           0             0           1               4      270000.0
# 3           1             0           1              20      283500.0
# 4           0             0           2               5      270000.0
#
#          Age  Years_employed           Income_type  \
# 0  32.868574       12.435574               Working
# ...

# %%
data.reset_index().plot.scatter(x='index', y='Num_children')
plt.show()

# %%
data.Num_children.unique().tolist()
# Out:
# [0, 1, 3, 2, 4, 5, 14, 19, 7]

# %%
data = data[data.Num_children != 19]
data = data[data.Num_children != 14]

# %%
print(data.corr())
# Out:
#                       ID    Gender   Own_car  Own_property  Work_phone  \
# ID              1.000000  0.014534 -0.003724     -0.071937    0.067580
# Gender          0.014534  1.000000  0.355264     -0.056123    0.059332
# Own_car        -0.003724  0.355264  1.000000     -0.010231    0.029635
# Own_property   -0.071937 -0.056123 -0.010231      1.000000   -0.184430
# Work_phone      0.067580  0.059332  0.029635     -0.184430    1.000000
# Phone           0.005262 -0.018920  0.004464     -0.052214    0.288090
# Email          -0.025052  0.006569  0.022282      0.056062   -0.040438
# Unemployed     -0.029422 -0.168747 -0.145487      0.086747   -0.242488
# Num_children    0.021044  0.056221  0.093528     -0.003675    0.051577
# Num_family      0.014647  0.080298  0.142326      0.006607    0.061298
# Account_length -0.005300 -0.008795  0.024714     -0.009667    0.015381
# Total_income   -0.003145  0.200667  0.221794      0.025583   -0.030702
# ...

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
data.columns.tolist()
# Out:
# ['ID',
#  'Gender',
#  'Own_car',
#  'Own_property',
#  'Work_phone',
#  'Phone',
#  'Email',
#  'Unemployed',
#  'Num_children',
#  'Num_family',
#  'Account_length',
#  'Total_income',
#  'Age',
#  'Years_employed',
#  'Income_type',
#  'Education_type',
#  'Family_status',
#  'Housing_type',
#  'Occupation_type',
#  'Target']

# %%
data['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data.Total_income, kde=True)
# Out:
# <AxesSubplot:xlabel='Total_income', ylabel='Count'>

# %%
data.Account_length.unique()
# Out:
# array([15, 29,  4, 20,  5, 17, 25, 31, 44, 24, 39, 43, 10, 21, 40, 11,  7,
#        12, 45, 49, 30, 22, 13, 16,  8, 34,  0,  3, 51, 46, 56, 38, 35, 33,
#        36, 27, 26,  6, 19, 47, 28, 60,  9, 57, 32, 55, 14, 23, 54, 58, 59,
#        42, 37, 41,  1, 48, 53, 50, 52, 18,  2])

# %%
# Out:
#            ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 124   5009543       0        0             0           0      0      0
# 465   5021544       0        0             1           0      0      0
# 471   5021568       0        0             1           0      1      1
# 490   5021662       1        0             1           1      0      0
# 609   5022429       0        0             1           0      0      0
# ...       ...     ...      ...           ...         ...    ...    ...
# 9218  5146024       0        0             1           0      1      0
# 9409  5149093       0        0             1           1      0      0
# 9496  5149698       1        0             1           0      0      0
# 9541  5149953       0        0             1           0      0      0
# 9573  5150208       0        0             1           0      0      0
#
#       Unemployed  Num_children  Num_family  Account_length  Total_income  \
# ...

# %%
sns.distplot(data['Age'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['Account_length'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Account_length', ylabel='Density'>

# %%
sns.distplot(data['Years_employed'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Years_employed', ylabel='Density'>

# %%
sns.distplot(data['Total_income'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_income', ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(15,3)})
plt.xticks(fontsize=15,rotation='vertical')
p=sns.countplot(data['Occupation_type'],hue_order=data.groupby('Occupation_type'))
p.axes.set_title("Amount of income per type",fontsize=30)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.columns
# Out:
# Index(['ID', 'Gender', 'Own_car', 'Own_property', 'Work_phone', 'Phone',
#        'Email', 'Unemployed', 'Num_children', 'Num_family', 'Account_length',
#        'Total_income', 'Age', 'Years_employed', 'Income_type',
#        'Education_type', 'Family_status', 'Housing_type', 'Occupation_type',
#        'Target'],
#       dtype='object')

# %%
sns.countplot(hue='Occupation_type',x='Own_car',data=data)
# Out:
# <AxesSubplot:xlabel='Own_car', ylabel='count'>

# %%
sns.countplot(hue='Own_property',x='Own_car',data=data)
# Out:
# <AxesSubplot:xlabel='Own_car', ylabel='count'>

# %%
sns.set()
cols = ['Age', 'Total_income', 'Account_length', 'Years_employed','Num_children']
sns.pairplot(data[cols], size = 2.5)
plt.show();
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Data Modeling
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/k0/5j31t_l12c38235_rztm0p880000gn/T/ipykernel_14644/1721589786.py in <module>
#       1 #Data Modeling
# ----> 2 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
data.head
# Out:
# <bound method NDFrame.head of            ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0     5008804       1        1             1           1      0      0
# 1     5008806       1        1             1           0      0      0
# 2     5008808       0        0             1           0      1      1
# 3     5008812       0        0             1           0      0      0
# 4     5008815       1        1             1           1      1      1
# ...       ...     ...      ...           ...         ...    ...    ...
# 9704  5148694       0        0             0           0      0      0
# 9705  5149055       0        0             1           1      1      0
# 9706  5149729       1        1             1           0      0      0
# 9707  5149838       0        0             1           0      1      1
# 9708  5150337       1        0             1           0      0      0
#
#       Unemployed  Num_children  Num_family  Account_length  Total_income  \
# ...
