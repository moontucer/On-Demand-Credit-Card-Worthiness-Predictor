# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"/Users/mountasser/Downloads/archive/application_record.csv")

# %%
data.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
data2 = pd.read_csv(r"/Users/mountasser/Downloads/archive/credit_record.csv")

# %%
data2.columns.tolist()
# Out:
# ['ID', 'MONTHS_BALANCE', 'STATUS']

# %%
del data2['MONTHS_BALANCE']
del data2['STATUS']

# %%
data2.columns.tolist()
# Out:
# ['ID']

# %%
clean_data = data_filtered.drop_duplicates()

# %%
data2.shape
# Out:
# (45985, 1)

# %%
data_filtered = data[data.OCCUPATION_TYPE.notnull()]

# %%
data_filtered = data[data.OCCUPATION_TYPE.notnull()]
data_filtered.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
# 5  5008810           F            N               Y             0
# 6  5008811           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
# 5          270000.0  Commercial associate  Secondary / secondary special
# 6          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
data_filtered.CODE_GENDER.unique().tolist()
# Out:
# ['M', 'F']

# %%
data_filtered.FLAG_OWN_CAR.unique().tolist()
# Out:
# ['Y', 'N']

# %%
data_filtered.FLAG_OWN_REALTY.unique().tolist()
# Out:
# ['Y', 'N']

# %%
data_filtered.CNT_CHILDREN.unique().tolist()
# Out:
# [0, 3, 1, 2, 4, 14, 5, 19, 7, 9, 12]

# %%
data_filtered.AMT_INCOME_TOTAL.unique().tolist()
# Out:
# [112500.0,
#  270000.0,
#  135000.0,
#  130500.0,
#  157500.0,
#  405000.0,
#  211500.0,
#  360000.0,
#  126000.0,
#  247500.0,
#  297000.0,
#  166500.0,
#  225000.0,
#  315000.0,
#  148500.0,
#  202500.0,
#  450000.0,
#  180000.0,
#  90000.0,
#  765000.0,
#  229500.0,
#  292500.0,
#  74250.0,
#  144000.0,
#  337500.0,
#  193500.0,
#  267750.0,
#  139500.0,
#  67500.0,
#  252000.0,
#  900000.0,
#  279000.0,
#  76500.0,
#  234000.0,
#  81000.0,
#  108000.0,
#  198000.0,
#  216000.0,
#  45000.0,
#  238500.0,
#  117000.0,
#  1350000.0,
#  99000.0,
#  445500.0,
#  427500.0,
#  306000.0,
#  328500.0,
#  310500.0,
#  540000.0,
#  171000.0,
#  675000.0,
#  121500.0,
#  72000.0,
#  184500.0,
#  189000.0,
#  243000.0,
#  94500.0,
#  256500.0,
#  697500.0,
#  196650.0,
#  40500.0,
#  432000.0,
#  162000.0,
#  103500.0,
#  257625.0,
#  58500.0,
#  207000.0,
#  720000.0,
#  261000.0,
#  175500.0,
#  382500.0,
#  119250.0,
#  63000.0,
#  274500.0,
#  90900.0,
#  495000.0,
#  220500.0,
# ...

# %%
data_filtered.NAME_INCOME_TYPE.unique().tolist()
# Out:
# ['Working', 'Commercial associate', 'State servant', 'Student', 'Pensioner']

# %%
data_filtered.NAME_EDUCATION_TYPE.unique().tolist()
# Out:
# ['Secondary / secondary special',
#  'Higher education',
#  'Incomplete higher',
#  'Lower secondary',
#  'Academic degree']

# %%
data_filtered.NAME_FAMILY_STATUS.unique().tolist()
# Out:
# ['Married', 'Single / not married', 'Civil marriage', 'Separated', 'Widow']

# %%
data_filtered.NAME_HOUSING_TYPE.unique().tolist()
# Out:
# ['House / apartment',
#  'Rented apartment',
#  'Municipal apartment',
#  'With parents',
#  'Co-op apartment',
#  'Office apartment']

# %%
data_filtered.DAYS_BIRTH.unique().tolist()
# Out:
# [-21474,
#  -19110,
#  -16872,
#  -17778,
#  -10669,
#  -10031,
#  -12689,
#  -11842,
#  -20502,
#  -15761,
#  -16212,
#  -16670,
#  -12411,
#  -17016,
#  -15519,
#  -13642,
#  -15484,
#  -17785,
#  -20874,
#  -16582,
#  -10628,
#  -9927,
#  -18926,
#  -19861,
#  -14450,
#  -10554,
#  -14326,
#  -17641,
#  -10997,
#  -8861,
#  -7489,
#  -10450,
#  -10264,
#  -17726,
#  -14122,
#  -10064,
#  -20531,
#  -14730,
#  -12628,
#  -12197,
#  -13679,
#  -13271,
#  -12859,
#  -15321,
#  -8842,
#  -9657,
#  -15825,
#  -19575,
#  -12915,
#  -18325,
#  -17573,
#  -20953,
#  -12333,
#  -14667,
#  -10611,
#  -19082,
#  -9957,
#  -15970,
#  -14562,
#  -10266,
#  -14781,
#  -15140,
#  -16099,
#  -20991,
#  -16203,
#  -18674,
#  -10750,
#  -21155,
#  -19692,
#  -19063,
#  -14867,
#  -11281,
#  -9430,
#  -14718,
#  -11042,
#  -12506,
#  -20604,
#  -10331,
#  -13923,
#  -19304,
#  -19569,
#  -8182,
#  -8657,
#  -14835,
#  -14435,
#  -17274,
#  -12130,
#  -16196,
#  -11706,
#  -16100,
#  -16888,
# ...

# %%
data_filtered.DAYS_EMPLOYED.unique().tolist()
# Out:
# [-1134,
#  -3051,
#  -769,
#  -1194,
#  -1103,
#  -1469,
#  -1163,
#  -2016,
#  -4450,
#  -3173,
#  -7099,
#  -5364,
#  -1773,
#  -1347,
#  -3234,
#  -4846,
#  -1408,
#  -1712,
#  -2381,
#  -828,
#  -6276,
#  -10843,
#  -2777,
#  -555,
#  -889,
#  -2289,
#  -797,
#  -2077,
#  -708,
#  -1286,
#  -5730,
#  -2989,
#  -4025,
#  -4391,
#  -4056,
#  -2747,
#  -312,
#  -1560,
#  -3720,
#  -2901,
#  -3174,
#  -1256,
#  -5792,
#  -8684,
#  -860,
#  -798,
#  -982,
#  -5243,
#  -921,
#  -8987,
#  -1287,
#  -1652,
#  -2443,
#  -4816,
#  -1866,
#  -4727,
#  -7100,
#  -5304,
#  -130,
#  -5273,
#  -7404,
#  -586,
#  -1744,
#  -1195,
#  -5578,
#  -495,
#  -252,
#  -433,
#  -2290,
#  -464,
#  -1013,
#  -1317,
#  -1164,
#  -3386,
#  -1348,
#  -6218,
#  -4939,
#  -2687,
#  -2170,
#  -1135,
#  -890,
#  -9748,
#  -3143,
#  -678,
#  -2748,
#  -99,
#  -3296,
#  -2047,
#  -283,
#  -3661,
#  -344,
#  -2474,
#  -7314,
#  -4392,
#  -1682,
#  -6826,
#  -3266,
#  -5457,
#  -374,
#  -1713,
#  -405,
#  -1470,
# ...

# %%
data_filtered.FLAG_MOBIL.unique().tolist()
# Out:
# [1]

# %%
data.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
data_filtered.FLAG_WORK_PHONE.unique().tolist()
# Out:
# [0, 1]

# %%
data_filtered.FLAG_PHONE.unique().tolist()
# Out:
# [0, 1]

# %%
data_filtered.FLAG_EMAIL.unique().tolist()
# Out:
# [0, 1]

# %%
data_filtered.OCCUPATION_TYPE.unique().tolist()
# Out:
# ['Security staff',
#  'Sales staff',
#  'Accountants',
#  'Laborers',
#  'Managers',
#  'Drivers',
#  'Core staff',
#  'High skill tech staff',
#  'Cleaning staff',
#  'Private service staff',
#  'Cooking staff',
#  'Low-skill Laborers',
#  'Medicine staff',
#  'Secretaries',
#  'Waiters/barmen staff',
#  'HR staff',
#  'Realty agents',
#  'IT staff']

# %%
data_filtered.CNT_FAM_MEMBERS.unique().tolist()
# Out:
# [2.0, 1.0, 5.0, 3.0, 4.0, 6.0, 15.0, 7.0, 20.0, 9.0, 11.0, 14.0]

# %%
data_filtered.info
# Out:
# <bound method DataFrame.info of              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# 5       5008810           F            N               Y             0
# 6       5008811           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438541  6837707           M            N               Y             0
# 438548  6839936           M            Y               Y             1
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
data_filtered.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  3.043540e+05  304354.000000      3.043540e+05  304354.000000
# mean   6.022984e+06       0.510977      1.948680e+05  -14806.806485
# std    5.698275e+05       0.765500      1.169721e+05    3487.223150
# min    5.008806e+06       0.000000      2.700000e+04  -24770.000000
# 25%    5.617726e+06       0.000000      1.350000e+05  -17439.000000
# 50%    6.047822e+06       0.000000      1.800000e+05  -14583.000000
# 75%    6.449036e+06       1.000000      2.250000e+05  -11944.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  304354.000000    304354.0    304354.000000  304354.000000
# mean    -2621.933357         1.0         0.248152       0.285559
# std      2400.254918         0.0         0.431941       0.451681
# min    -17531.000000         1.0         0.000000       0.000000
# ...

# %%
data_filtered.DAYS_BIRTH = data_filtered.DAYS_BIRTH*-1
# Out:
# /var/folders/k0/5j31t_l12c38235_rztm0p880000gn/T/ipykernel_7355/2383251336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered.DAYS_BIRTH = data_filtered.DAYS_BIRTH*-1

# %%
data_filtered.DAYS_EMPLOYED = data_filtered.DAYS_EMPLOYED*-1
# Out:
# /var/folders/k0/5j31t_l12c38235_rztm0p880000gn/T/ipykernel_7355/1388990055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered.DAYS_EMPLOYED = data_filtered.DAYS_EMPLOYED*-1

# %%
data_filtered.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
del data_filtered['ID']

# %%
del data_filtered['FLAG_MOBIL']

# %%
data_filtered.columns
# Out:
# Index(['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL',
#        'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
clean_data = data_filtered.drop_duplicates()

# %%
clean_data.shape
# Out:
# (62608, 16)

# %%
clean_data.columns
# Out:
# Index(['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL',
#        'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
clean_data.reset_index(inplace = True, drop = True)

# %%
clean_data.head()
# Out:
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0           M            Y               Y             0          112500.0
# 1           F            N               Y             0          270000.0
# 2           M            Y               Y             0          270000.0
# 3           M            Y               Y             0          135000.0
# 4           F            Y               N             0          130500.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               Working  Secondary / secondary special               Married
# 1  Commercial associate  Secondary / secondary special  Single / not married
# 2               Working               Higher education               Married
# 3  Commercial associate  Secondary / secondary special               Married
# 4               Working              Incomplete higher               Married
#
# ...

# %%
# Days employed plot
clean_data.reset_index().plot.scatter(x='index', y='DAYS_EMPLOYED')
plt.show()

# %%
# Days employed plot
clean_data.reset_index().plot.scatter(x='index', y='CNT_FAM_MEMBERS')
plt.show()

# %%
clean_data.columns
# Out:
# Index(['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL',
#        'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS'],
#       dtype='object')

# %%
# Days employed plot
clean_data.reset_index().plot.scatter(x='index', y='CNT_CHILDREN')
plt.show()
